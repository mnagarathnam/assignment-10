# %%
#Q> create and import below files

#1. Create a friend_names.xls file  (atleast 10 names, columns are FriendName,Quality)
#Q1> create a dataframe which contains only your intelligent friends list.
#Q2> create a dataframe which contains only your funny friends list.

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"D:\swathi\bujji\friends names.xlsx")
df
# Out:
#     friends      quality
# 0  prasanna  intilligent
# 1     swati       active
# 2     durga  intilligent
# 3   jayasri       active
# 4   shabana       silent
# 5   shahena       silent
# 6    parvin       active
# 7   santosh          joy
# 8      kaza         good
# 9     mouni        funny

# %%
#Q1> create a dataframe which contains only your intelligent friends list.

# %%
a=df[df["quality"]=="intilligent"]
a
# Out:
#     friends      quality
# 0  prasanna  intilligent
# 2     durga  intilligent

# %%
#Q2> create a dataframe which contains only your funny friends list.

# %%
b=df[df["quality"]=="funny"]
b
# Out:
#   friends quality
# 9   mouni   funny

# %%
#2. Create a family_members.xls file  (atleast 10 names, columns are FamilyMemberName*Relation)
#Q1> create a dataframe which contains only your brothers and sisters list.
#Q2> create a dataframe which contains only your parents list.
#Q3> create a dataframe which not contains your parents list.
#Q4> create a dataframe which not contains your brothers list.
#Q5> create a dataframe which contains either your brothers list or parents list.
#Q5> create a dataframe which contains your brothers list and parents list.

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"D:\swathi\bujji\family.xlsx")
df
# Out:
#    family_members  relation
# 0           sunil   husband
# 1            siri  daughter
# 2        govardan       son
# 3           samba   brother
# 4            raja   brother
# 5          himaja    sister
# 6          chinni    sister
# 7          rajita    sister
# 8          venkat   brother
# 9       durga rao   parents
# 10   siva parvati   parents

# %%
#Q1> create a dataframe which contains only your brothers and sisters list.

# %%
lst=["brother","sister"]
relation=df[df.relation.isin(lst)]
relation
# Out:
#   family_members relation
# 3          samba  brother
# 4           raja  brother
# 5         himaja   sister
# 6         chinni   sister
# 7         rajita   sister
# 8         venkat  brother

# %%
#Q2> create a dataframe which contains only your parents list.

# %%
y=df[(df["relation"]=="parents")]
y
# Out:
#    family_members relation
# 9       durga rao  parents
# 10   siva parvati  parents

# %%
#Q3> create a dataframe which not contains your parents list.

# %%
z=df[~(df["relation"]=="parents")]
z
# Out:
#   family_members  relation
# 0          sunil   husband
# 1           siri  daughter
# 2       govardan       son
# 3          samba   brother
# 4           raja   brother
# 5         himaja    sister
# 6         chinni    sister
# 7         rajita    sister
# 8         venkat   brother

# %%
#Q4> create a dataframe which not contains your brothers list.

# %%
a=df[~(df["relation"]=="brother")]
a
# Out:
#    family_members  relation
# 0           sunil   husband
# 1            siri  daughter
# 2        govardan       son
# 5          himaja    sister
# 6          chinni    sister
# 7          rajita    sister
# 9       durga rao   parents
# 10   siva parvati   parents

# %%
#Q5> create a dataframe which contains either your brothers list or parents list.

# %%
lst=["brother","parents"]
relation=df[~df.relation.isin(lst)]
relation
# Out:
#   family_members  relation
# 0          sunil   husband
# 1           siri  daughter
# 2       govardan       son
# 5         himaja    sister
# 6         chinni    sister
# 7         rajita    sister

# %%
#Q6> create a dataframe which contains your brothers list and parents list.

# %%
lst=["brother","parents"]
relation=df[df.relation.isin(lst)]
relation
# Out:
#    family_members relation
# 3           samba  brother
# 4            raja  brother
# 8          venkat  brother
# 9       durga rao  parents
# 10   siva parvati  parents

# %%
#3. Create a Vegfood_items.xlsx file  (atleast 10 names, columns are VegFoodName*Taste)
#Q1>create a dataframe which are  soups items
#Q2>create a dataframe which are curry items
#Q3>create a dataframe which are fry items
#Q4>create a dataframe which contains soups and fry items
#Q5>create a dataframe which not contains soups and fry items
#Q6>create a dataframe which contains either soup or fry items

# %%
import pandas
import pandas as pd
df1=pd.read_excel(r"D:\swathi\bujji\bujji - Copy\fry items.xlsx")
df1
# Out:
#          veg_items    taste
# 0          alu_fry    tasty
# 1   ladtfinger_fry     good
# 2    bringal_curry    super
# 3      tomato_soup    salty
# 4  drumstick_curry  v.tasty
# 5       beans_soup       ok
# 6   sweetcorn_soup    super

# %%
#Q1>create a dataframe which are  soups items

# %%
lst=["tomato_soup","beans_soup","sweetcorn_soup"]
veg=df1[df1.veg_items.isin(lst)]
veg
# Out:
#         veg_items  taste
# 3     tomato_soup  salty
# 5      beans_soup     ok
# 6  sweetcorn_soup  super

# %%
#Q2>create a dataframe which are curry items

# %%
lst=["bringal_curry","drumstick_curry"]
veg=df1[df1.veg_items.isin(lst)]
veg
# Out:
#          veg_items    taste
# 2    bringal_curry    super
# 4  drumstick_curry  v.tasty

# %%
#Q3>create a dataframe which are fry items

# %%
lst=["alu_fry","ladtfinger_fry"]
veg=df1[df1.veg_items.isin(lst)]
veg
# Out:
#         veg_items  taste
# 0         alu_fry  tasty
# 1  ladtfinger_fry   good

# %%
#Q4>create a dataframe which contains soups and fry items

# %%
lst=["tomato_soup","beans_soup","sweetcorn_soup","alu_fry","ladtfinger_fry"]
veg=df1[df1.veg_items.isin(lst)]
veg
# Out:
#         veg_items  taste
# 0         alu_fry  tasty
# 1  ladtfinger_fry   good
# 3     tomato_soup  salty
# 5      beans_soup     ok
# 6  sweetcorn_soup  super

# %%
#Q5>create a dataframe which not contains soups and fry items

# %%
lst=["tomato_soup","beans_soup","sweetcorn_soup","alu_fry","ladtfinger_fry"]
veg=df1[~df1.veg_items.isin(lst)]
veg
# Out:
#          veg_items    taste
# 2    bringal_curry    super
# 4  drumstick_curry  v.tasty

# %%
#Q6>create a dataframe which contains either soup or fry items

# %%
lst=["tomato_soup","beans_soup","sweetcorn_soup","alu_fry","ladtfinger_fry"]
veg=df1[df1.veg_items.isin(lst)]
veg
# Out:
#         veg_items  taste
# 0         alu_fry  tasty
# 1  ladtfinger_fry   good
# 3     tomato_soup  salty
# 5      beans_soup     ok
# 6  sweetcorn_soup  super

# %%
#4. Create a NonVegfood_items.xlsx file  (atleast 10 names, columns are NonVegFoodName*Taste)
#Q1>create a dataframe which contains only chicken items
#Q2>create a dataframe which contains only mutton items
#Q3>create a dataframe which contains only Fry items
#Q4>create a dataframe which contains only Fry and chicken items
#Q5>create a dataframe which not contains Fry and chicken items
#Q6>create a dataframe which contains either Fry or mutton items

# %%
import pandas
import pandas as pd
df1=pd.read_excel(r"D:\swathi\bujji\nonveg food.xlsx")
df1
# Out:
#        nonveg_items    taste
# 0           chicken    v.hot
# 1       mutton-soup      hot
# 2            france     good
# 3           egg fry    tasty
# 4       egg biryani      hot
# 5              fish     good
# 6            mutton      hot
# 7   chicken-biryani     good
# 8        fr.biryani  v.tasty
# 9           fishfry    yummy
# 10        fish-soup     sour

# %%
#Q1>create a dataframe which contains only chicken items.

# %%
lst=["chicken","chicken-biryani"]
nonveg=df1[df1.nonveg_items.isin(lst)]
nonveg
# Out:
#       nonveg_items  taste
# 0          chicken  v.hot
# 7  chicken-biryani   good

# %%
#Q2>create a dataframe which contains only mutton items

# %%
lst=["mutton","mutton-soup"]
nonveg=df1[df1.nonveg_items.isin(lst)]
nonveg
# Out:
#   nonveg_items taste
# 1  mutton-soup   hot
# 6       mutton   hot

# %%
#Q3>create a dataframe which contains only Fry items

# %%
lst=["fishfry","egg fry"]
nonveg=df1[df1.nonveg_items.isin(lst)]
nonveg
# Out:
#   nonveg_items  taste
# 3      egg fry  tasty
# 9      fishfry  yummy

# %%
#Q4>create a dataframe which contains only Fry and chicken items

# %%
lst=["fishfry","egg fry","chicken","chicken-biryani"]
nonveg=df1[df1.nonveg_items.isin(lst)]
nonveg
# Out:
#       nonveg_items  taste
# 0          chicken  v.hot
# 3          egg fry  tasty
# 7  chicken-biryani   good
# 9          fishfry  yummy

# %%
#Q5>create a dataframe which not contains Fry and chicken items

# %%
lst=["fishfry","egg fry","chicken","chicken-biryani"]
nonveg=df1[~df1.nonveg_items.isin(lst)]
nonveg
# Out:
#    nonveg_items    taste
# 1   mutton-soup      hot
# 2        france     good
# 4   egg biryani      hot
# 5          fish     good
# 6        mutton      hot
# 8    fr.biryani  v.tasty
# 10    fish-soup     sour

# %%
#Q6>create a dataframe which contains either Fry or mutton items

# %%
lst=["fishfry","egg fry","mutton","mutton-soup"]
nonveg=df1[df1.nonveg_items.isin(lst)]
nonveg
# Out:
#   nonveg_items  taste
# 1  mutton-soup    hot
# 3      egg fry  tasty
# 6       mutton    hot
# 9      fishfry  yummy

# %%
#5. Create a month_names.xlsx file (atleast 12 names, columns are MonthName*Season)
#Q1>create a dataframe which contains only winter season months
#Q2>create a dataframe which contains only summer season months
#Q3>create a dataframe which contains only rainy season months
#Q4>create a dataframe which contains only winter and summer season months
#Q5>create a dataframe which not contains summer and rainy season months
#Q6>create a dataframe which contains either winter or rainy items

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"D:\swathi\bujji\month_names.xlsx")
df
# Out:
#    month_names  season
# 0      january  winter
# 1     february  winter
# 2        march  summer
# 3        april  summer
# 4          may  summer
# 5         june  summer
# 6         july   rainy
# 7       august   rainy
# 8    september   rainy
# 9      october   rainy
# 10    november  winter
# 11    december  winter

# %%
#Q1>create a dataframe which contains only winter season months

# %%
a=df[df["season"]=="winter"]
a
# Out:
#    month_names  season
# 0      january  winter
# 1     february  winter
# 10    november  winter
# 11    december  winter

# %%
#Q2>create a dataframe which contains only summer season months

# %%
b=df[df["season"]=="summer"]
b
# Out:
#   month_names  season
# 2       march  summer
# 3       april  summer
# 4         may  summer
# 5        june  summer

# %%
#Q3>create a dataframe which contains only rainy season months

# %%
c=df[df["season"]=="rainy"]
c
# Out:
#   month_names season
# 6        july  rainy
# 7      august  rainy
# 8   september  rainy
# 9     october  rainy

# %%
#Q4>create a dataframe which contains only winter and summer season months.

# %%
lst=["winter","summer"]
months=df[df.season.isin(lst)]
months
# Out:
#    month_names  season
# 0      january  winter
# 1     february  winter
# 2        march  summer
# 3        april  summer
# 4          may  summer
# 5         june  summer
# 10    november  winter
# 11    december  winter

# %%
#Q5>create a dataframe which not contains summer and rainy season months.

# %%
lst=["rainy","summer"]
months=df[~df.season.isin(lst)]
months
# Out:
#    month_names  season
# 0      january  winter
# 1     february  winter
# 10    november  winter
# 11    december  winter

# %%
#Q6>create a dataframe which contains either winter or rainy items.

# %%
lst=["rainy","winter"]
months=df[df.season.isin(lst)]
months
# Out:
#    month_names  season
# 0      january  winter
# 1     february  winter
# 6         july   rainy
# 7       august   rainy
# 8    september   rainy
# 9      october   rainy
# 10    november  winter
# 11    december  winter

# %%
#6. Create a flower_names.xlsx file  (atleast 12 names, columns are FlowercolourName_in_English^FlowercolourName_in_Hindi^FlowercolourName_in_Telugu)
#Q1>create a dataframe which contains only red colour flower list
#Q2>create a dataframe which contains only white colour flower list
#Q3>create a dataframe which contains only pink colour flower list
#Q4>create a dataframe which contains only red and pink colour list
#Q5>create a dataframe which not contains red and white colour list
#Q6>create a dataframe which contains either red or pink colour list

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"D:\swathi\bujji\bujji - Copy\flowers.xlsx")
df
# Out:
#      flowers colours    telugu      hindi    english
# 0      rose     pink    gulabi     gulaab       rose
# 1    jasmine   white     malli   chamelee    jasmine
# 2  marrygold  yellow  chamanti   chamanti  marrygold
# 3    ganneru    pink   ganneru    ganneru    ganneru
# 4      lilly   white     lilly      lilee      lilly
# 5      tulip     red     tulip    tyoolip      tulip
# 6   mandaram     red  mandaram  japaapush   hibiscus

# %%
#Q1>create a dataframe which contains only red colour flower list.

# %%
a=df[df["colours"]=="red"]
a
# Out:
#     flowers colours    telugu      hindi   english
# 5     tulip     red     tulip    tyoolip     tulip
# 6  mandaram     red  mandaram  japaapush  hibiscus

# %%
#Q2>create a dataframe which contains only white colour flower list.

# %%
b=df[df["colours"]=="white"]
b
# Out:
#    flowers colours telugu     hindi  english
# 1  jasmine   white  malli  chamelee  jasmine
# 4    lilly   white  lilly     lilee    lilly

# %%
#Q3>create a dataframe which contains only pink colour flower list.

# %%
c=df[df["colours"]=="pink"]
c
# Out:
#    flowers colours   telugu    hindi  english
# 0    rose     pink   gulabi   gulaab     rose
# 3  ganneru    pink  ganneru  ganneru  ganneru

# %%
#Q4>create a dataframe which contains only red and pink colour list.

# %%
lst=["pink","red"]
flowers=df[df.colours.isin(lst)]
flowers
# Out:
#     flowers colours    telugu      hindi   english
# 0     rose     pink    gulabi     gulaab      rose
# 3   ganneru    pink   ganneru    ganneru   ganneru
# 5     tulip     red     tulip    tyoolip     tulip
# 6  mandaram     red  mandaram  japaapush  hibiscus

# %%
#Q5>create a dataframe which not contains red and white colour list.

# %%
lst=["white","red"]
months=df[~df.colours.isin(lst)]
months
# Out:
#      flowers colours    telugu     hindi    english
# 0      rose     pink    gulabi    gulaab       rose
# 2  marrygold  yellow  chamanti  chamanti  marrygold
# 3    ganneru    pink   ganneru   ganneru    ganneru

# %%
#Q6>create a dataframe which contains either red or pink colour list.

# %%
lst=["pink","red"]
months=df[df.colours.isin(lst)]
months
# Out:
#     flowers colours    telugu      hindi   english
# 0     rose     pink    gulabi     gulaab      rose
# 3   ganneru    pink   ganneru    ganneru   ganneru
# 5     tulip     red     tulip    tyoolip     tulip
# 6  mandaram     red  mandaram  japaapush  hibiscus
